# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
            
plt.rcParams["figure.figsize"] = (11,7)

# %%
data = pd.read_csv('../csv_files/toplot_gapminder.csv')

# %%
data.head()
# Out:
#          Country  Year   AgriLand  ChildrenPerWoman  DemocracyScore  \
# 0    Afghanistan  1952  58.190873             7.671      -10.000000
# 1        Albania  1952  41.885645             6.071       -9.000000
# 2        Algeria  1952  17.529796             7.648       -5.916667
# 3  AmericanSamoa  1952  20.833333             0.000        0.000000
# 4        Andorra  1952  44.503546             0.000        0.000000
#
#      Exports  FemaleParticipation  ForestArea  GDPpercapita  \
# 0  17.562747            29.514286     13500.0      0.000000
# 1  18.863361            71.500000      7690.0   1154.008464
# 2  29.990094            29.185714     15790.0   1705.202014
# 3   0.000000             0.000000       180.0      0.000000
# 4   0.000000             0.000000       160.0  17383.862582
#
#    HealthSpendPerPerson  ...  LifeExpectancy  LiteracyRateAdult  \
# 0              2.679386  ...          27.448            0.00000
# ...

# %%
years = data.Year.unique()

# %%
plt.plot(years, data.AgriLand[data["Country"] == 'Cyprus'], 'violet', label="Cyprus")
plt.plot(years, data.AgriLand[data["Country"] == 'Singapore'], 'red', label="Singapore")
plt.plot(years, data.AgriLand[data["Country"] == 'Denmark'], 'brown', label="Denmark")
plt.plot(years, data.AgriLand[data["Country"] == 'China'], 'blue', label="China")
plt.plot(years, data.AgriLand[data["Country"] == 'UnitedStatesofAmerica'], 'black', label="USA")
plt.plot(years, data.AgriLand[data["Country"] == 'Pakistan'], 'green', label="Pakistan")
plt.plot(years, data.AgriLand[data["Country"] == 'India'], 'orange', label="India")


plt.title('Agricultural Land')
plt.legend()

# %%
plt.show()

# %%
plt.plot(years, data.ChildrenPerWoman[data["Country"] == 'Cyprus'], 'violet', label="Cyprus")
plt.plot(years, data.ChildrenPerWoman[data["Country"] == 'Singapore'], 'red', label="Singapore")
plt.plot(years, data.ChildrenPerWoman[data["Country"] == 'Denmark'], 'brown', label="Denmark")
plt.plot(years, data.ChildrenPerWoman[data["Country"] == 'China'], 'blue', label="China")
plt.plot(years, data.ChildrenPerWoman[data["Country"] == 'UnitedStatesofAmerica'], 'black', label="USA")
plt.plot(years, data.ChildrenPerWoman[data["Country"] == 'Pakistan'], 'green', label="Pakistan")
plt.plot(years, data.ChildrenPerWoman[data["Country"] == 'India'], 'orange', label="India")


plt.title('Children Per Woman')
plt.legend()

# %%
plt.plot(years, data.DemocracyScore[data["Country"] == 'Cyprus'], 'violet', label="Cyprus")
plt.plot(years, data.DemocracyScore[data["Country"] == 'Singapore'], 'red', label="Singapore")
plt.plot(years, data.DemocracyScore[data["Country"] == 'Denmark'], 'brown', label="Denmark")
plt.plot(years, data.DemocracyScore[data["Country"] == 'China'], 'blue', label="China")
plt.plot(years, data.DemocracyScore[data["Country"] == 'UnitedStatesofAmerica'], 'black', label="USA")
plt.plot(years, data.DemocracyScore[data["Country"] == 'Pakistan'], 'green', label="Pakistan")
plt.plot(years, data.DemocracyScore[data["Country"] == 'India'], 'orange', label="India")


plt.title('Democracy Score')
plt.legend()

# %%
plt.plot(years, data.Exports[data["Country"] == 'Cyprus'], 'violet', label="Cyprus")
plt.plot(years, data.Exports[data["Country"] == 'Singapore'], 'red', label="Singapore")
plt.plot(years, data.Exports[data["Country"] == 'Denmark'], 'brown', label="Denmark")
plt.plot(years, data.Exports[data["Country"] == 'China'], 'blue', label="China")
plt.plot(years, data.Exports[data["Country"] == 'UnitedStatesofAmerica'], 'black', label="USA")
plt.plot(years, data.Exports[data["Country"] == 'Pakistan'], 'green', label="Pakistan")
plt.plot(years, data.Exports[data["Country"] == 'India'], 'orange', label="India")


plt.title('Exports')
plt.legend()

# %%
plt.plot(years, data.FemaleParticipation[data["Country"] == 'Cyprus'], 'violet', label="Cyprus")
plt.plot(years, data.FemaleParticipation[data["Country"] == 'Singapore'], 'red', label="Singapore")
plt.plot(years, data.FemaleParticipation[data["Country"] == 'Denmark'], 'brown', label="Denmark")
plt.plot(years, data.FemaleParticipation[data["Country"] == 'China'], 'blue', label="China")
plt.plot(years, data.FemaleParticipation[data["Country"] == 'UnitedStatesofAmerica'], 'black', label="USA")
plt.plot(years, data.FemaleParticipation[data["Country"] == 'Pakistan'], 'green', label="Pakistan")
plt.plot(years, data.FemaleParticipation[data["Country"] == 'India'], 'orange', label="India")


plt.title('Female Participation')
plt.legend()

# %%
plt.plot(years, data.ForestArea[data["Country"] == 'Cyprus'], 'violet', label="Cyprus")
plt.plot(years, data.ForestArea[data["Country"] == 'Singapore'], 'red', label="Singapore")
plt.plot(years, data.ForestArea[data["Country"] == 'Denmark'], 'brown', label="Denmark")
plt.plot(years, data.ForestArea[data["Country"] == 'China'], 'blue', label="China")
plt.plot(years, data.ForestArea[data["Country"] == 'UnitedStatesofAmerica'], 'black', label="USA")
plt.plot(years, data.ForestArea[data["Country"] == 'Pakistan'], 'green', label="Pakistan")
plt.plot(years, data.ForestArea[data["Country"] == 'India'], 'orange', label="India")


plt.title('Forest Area')
plt.legend()

# %%
plt.plot(years, data.GDPpercapita[data["Country"] == 'Cyprus'], 'violet', label="Cyprus")
plt.plot(years, data.GDPpercapita[data["Country"] == 'Singapore'], 'red', label="Singapore")
plt.plot(years, data.GDPpercapita[data["Country"] == 'Denmark'], 'brown', label="Denmark")
plt.plot(years, data.GDPpercapita[data["Country"] == 'China'], 'blue', label="China")
plt.plot(years, data.GDPpercapita[data["Country"] == 'UnitedStatesofAmerica'], 'black', label="USA")
plt.plot(years, data.GDPpercapita[data["Country"] == 'Pakistan'], 'green', label="Pakistan")
plt.plot(years, data.GDPpercapita[data["Country"] == 'India'], 'orange', label="India")


plt.title('GDP Per Capita')
plt.legend()

# %%
plt.plot(years, data.HealthSpendPerPerson[data["Country"] == 'Cyprus'], 'violet', label="Cyprus")
plt.plot(years, data.HealthSpendPerPerson[data["Country"] == 'Singapore'], 'red', label="Singapore")
plt.plot(years, data.HealthSpendPerPerson[data["Country"] == 'Denmark'], 'brown', label="Denmark")
plt.plot(years, data.HealthSpendPerPerson[data["Country"] == 'China'], 'blue', label="China")
plt.plot(years, data.HealthSpendPerPerson[data["Country"] == 'UnitedStatesofAmerica'], 'black', label="USA")
plt.plot(years, data.HealthSpendPerPerson[data["Country"] == 'Pakistan'], 'green', label="Pakistan")
plt.plot(years, data.HealthSpendPerPerson[data["Country"] == 'India'], 'orange', label="India")


plt.title('Health Spend Per Person')
plt.legend()

# %%
plt.plot(years, data.Hightotechnologyexports[data["Country"] == 'Cyprus'], 'violet', label="Cyprus")
plt.plot(years, data.Hightotechnologyexports[data["Country"] == 'Singapore'], 'red', label="Singapore")
plt.plot(years, data.Hightotechnologyexports[data["Country"] == 'Denmark'], 'brown', label="Denmark")
plt.plot(years, data.Hightotechnologyexports[data["Country"] == 'China'], 'blue', label="China")
plt.plot(years, data.Hightotechnologyexports[data["Country"] == 'UnitedStatesofAmerica'], 'black', label="USA")
plt.plot(years, data.Hightotechnologyexports[data["Country"] == 'Pakistan'], 'green', label="Pakistan")
plt.plot(years, data.Hightotechnologyexports[data["Country"] == 'India'], 'orange', label="India")


plt.title('High to Technology Exports')
plt.legend()

# %%
plt.plot(years, data.Imports[data["Country"] == 'Cyprus'], 'violet', label="Cyprus")
plt.plot(years, data.Imports[data["Country"] == 'Singapore'], 'red', label="Singapore")
plt.plot(years, data.Imports[data["Country"] == 'Denmark'], 'brown', label="Denmark")
plt.plot(years, data.Imports[data["Country"] == 'China'], 'blue', label="China")
plt.plot(years, data.Imports[data["Country"] == 'UnitedStatesofAmerica'], 'black', label="USA")
plt.plot(years, data.Imports[data["Country"] == 'Pakistan'], 'green', label="Pakistan")
plt.plot(years, data.Imports[data["Country"] == 'India'], 'orange', label="India")


plt.title('Imports')
plt.legend()

# %%
plt.plot(years, data.IncomePerPerson[data["Country"] == 'Cyprus'], 'violet', label="Cyprus")
plt.plot(years, data.IncomePerPerson[data["Country"] == 'Singapore'], 'red', label="Singapore")
plt.plot(years, data.IncomePerPerson[data["Country"] == 'Denmark'], 'brown', label="Denmark")
plt.plot(years, data.IncomePerPerson[data["Country"] == 'China'], 'blue', label="China")
plt.plot(years, data.IncomePerPerson[data["Country"] == 'UnitedStatesofAmerica'], 'black', label="USA")
plt.plot(years, data.IncomePerPerson[data["Country"] == 'Pakistan'], 'green', label="Pakistan")
plt.plot(years, data.IncomePerPerson[data["Country"] == 'India'], 'orange', label="India")


plt.title('Income Per Person')
plt.legend()

# %%
plt.plot(years, data.Incomeshareofrichest10pct[data["Country"] == 'Cyprus'], 'violet', label="Cyprus")
plt.plot(years, data.Incomeshareofrichest10pct[data["Country"] == 'Singapore'], 'red', label="Singapore")
plt.plot(years, data.Incomeshareofrichest10pct[data["Country"] == 'Denmark'], 'brown', label="Denmark")
plt.plot(years, data.Incomeshareofrichest10pct[data["Country"] == 'China'], 'blue', label="China")
plt.plot(years, data.Incomeshareofrichest10pct[data["Country"] == 'UnitedStatesofAmerica'], 'black', label="USA")
plt.plot(years, data.Incomeshareofrichest10pct[data["Country"] == 'Pakistan'], 'green', label="Pakistan")
plt.plot(years, data.Incomeshareofrichest10pct[data["Country"] == 'India'], 'orange', label="India")


plt.title('Income Share Of Richest 10pct')
plt.legend()

# %%
plt.plot(years, data.Infantmortality[data["Country"] == 'Cyprus'], 'violet', label="Cyprus")
plt.plot(years, data.Infantmortality[data["Country"] == 'Singapore'], 'red', label="Singapore")
plt.plot(years, data.Infantmortality[data["Country"] == 'Denmark'], 'brown', label="Denmark")
plt.plot(years, data.Infantmortality[data["Country"] == 'China'], 'blue', label="China")
plt.plot(years, data.Infantmortality[data["Country"] == 'UnitedStatesofAmerica'], 'black', label="USA")
plt.plot(years, data.Infantmortality[data["Country"] == 'Pakistan'], 'green', label="Pakistan")
plt.plot(years, data.Infantmortality[data["Country"] == 'India'], 'orange', label="India")


plt.title('Infant Mortality')
plt.legend()

# %%
plt.plot(years, data.Inflation[data["Country"] == 'Cyprus'], 'violet', label="Cyprus")
plt.plot(years, data.Inflation[data["Country"] == 'Singapore'], 'red', label="Singapore")
plt.plot(years, data.Inflation[data["Country"] == 'Denmark'], 'brown', label="Denmark")
plt.plot(years, data.Inflation[data["Country"] == 'China'], 'blue', label="China")
plt.plot(years, data.Inflation[data["Country"] == 'UnitedStatesofAmerica'], 'black', label="USA")
plt.plot(years, data.Inflation[data["Country"] == 'Pakistan'], 'green', label="Pakistan")
plt.plot(years, data.Inflation[data["Country"] == 'India'], 'orange', label="India")


plt.title('Inflation')
plt.legend()

# %%
plt.plot(years, data.Internetusers[data["Country"] == 'Cyprus'], 'violet', label="Cyprus")
plt.plot(years, data.Internetusers[data["Country"] == 'Singapore'], 'red', label="Singapore")
plt.plot(years, data.Internetusers[data["Country"] == 'Denmark'], 'brown', label="Denmark")
plt.plot(years, data.Internetusers[data["Country"] == 'China'], 'blue', label="China")
plt.plot(years, data.Internetusers[data["Country"] == 'UnitedStatesofAmerica'], 'black', label="USA")
plt.plot(years, data.Internetusers[data["Country"] == 'Pakistan'], 'green', label="Pakistan")
plt.plot(years, data.Internetusers[data["Country"] == 'India'], 'orange', label="India")


plt.title('Internet Users')
plt.legend()

# %%
plt.plot(years, data.LifeExpectancy[data["Country"] == 'Cyprus'], 'violet', label="Cyprus")
plt.plot(years, data.LifeExpectancy[data["Country"] == 'Singapore'], 'red', label="Singapore")
plt.plot(years, data.LifeExpectancy[data["Country"] == 'Denmark'], 'brown', label="Denmark")
plt.plot(years, data.LifeExpectancy[data["Country"] == 'China'], 'blue', label="China")
plt.plot(years, data.LifeExpectancy[data["Country"] == 'UnitedStatesofAmerica'], 'black', label="USA")
plt.plot(years, data.LifeExpectancy[data["Country"] == 'Pakistan'], 'green', label="Pakistan")
plt.plot(years, data.LifeExpectancy[data["Country"] == 'India'], 'orange', label="India")


plt.title('Life Expectancy')
plt.legend()

# %%
plt.plot(years, data.LiteracyRateAdult[data["Country"] == 'Cyprus'], 'violet', label="Cyprus")
plt.plot(years, data.LiteracyRateAdult[data["Country"] == 'Singapore'], 'red', label="Singapore")
plt.plot(years, data.LiteracyRateAdult[data["Country"] == 'Denmark'], 'brown', label="Denmark")
plt.plot(years, data.LiteracyRateAdult[data["Country"] == 'China'], 'blue', label="China")
plt.plot(years, data.LiteracyRateAdult[data["Country"] == 'UnitedStatesofAmerica'], 'black', label="USA")
plt.plot(years, data.LiteracyRateAdult[data["Country"] == 'Pakistan'], 'green', label="Pakistan")
plt.plot(years, data.LiteracyRateAdult[data["Country"] == 'India'], 'orange', label="India")


plt.title('Literacy Rate Adult')
plt.legend()

# %%
plt.plot(years, data.LIteracyRateYouth[data["Country"] == 'Cyprus'], 'violet', label="Cyprus")
plt.plot(years, data.LIteracyRateYouth[data["Country"] == 'Singapore'], 'red', label="Singapore")
plt.plot(years, data.LIteracyRateYouth[data["Country"] == 'Denmark'], 'brown', label="Denmark")
plt.plot(years, data.LIteracyRateYouth[data["Country"] == 'China'], 'blue', label="China")
plt.plot(years, data.LIteracyRateYouth[data["Country"] == 'UnitedStatesofAmerica'], 'black', label="USA")
plt.plot(years, data.LIteracyRateYouth[data["Country"] == 'Pakistan'], 'green', label="Pakistan")
plt.plot(years, data.LIteracyRateYouth[data["Country"] == 'India'], 'orange', label="India")


plt.title('LIteracy Rate Youth')
plt.legend()

# %%
plt.plot(years, data.Populationdensity[data["Country"] == 'Cyprus'], 'violet', label="Cyprus")
plt.plot(years, data.Populationdensity[data["Country"] == 'Singapore'], 'red', label="Singapore")
plt.plot(years, data.Populationdensity[data["Country"] == 'Denmark'], 'brown', label="Denmark")
plt.plot(years, data.Populationdensity[data["Country"] == 'China'], 'blue', label="China")
plt.plot(years, data.Populationdensity[data["Country"] == 'UnitedStatesofAmerica'], 'black', label="USA")
plt.plot(years, data.Populationdensity[data["Country"] == 'Pakistan'], 'green', label="Pakistan")
plt.plot(years, data.Populationdensity[data["Country"] == 'India'], 'orange', label="India")


plt.title('Population Density')
plt.legend()

# %%
plt.plot(years, data.ElectricityPerPerson[data["Country"] == 'Cyprus'], 'violet', label="Cyprus")
plt.plot(years, data.ElectricityPerPerson[data["Country"] == 'Singapore'], 'red', label="Singapore")
plt.plot(years, data.ElectricityPerPerson[data["Country"] == 'Denmark'], 'brown', label="Denmark")
plt.plot(years, data.ElectricityPerPerson[data["Country"] == 'China'], 'blue', label="China")
plt.plot(years, data.ElectricityPerPerson[data["Country"] == 'UnitedStatesofAmerica'], 'black', label="USA")
plt.plot(years, data.ElectricityPerPerson[data["Country"] == 'Pakistan'], 'green', label="Pakistan")
plt.plot(years, data.ElectricityPerPerson[data["Country"] == 'India'], 'orange', label="India")


plt.title('Electricity Per Person')
plt.legend()

# %%
plt.plot(years, data.Taxrevenue[data["Country"] == 'Cyprus'], 'violet', label="Cyprus")
plt.plot(years, data.Taxrevenue[data["Country"] == 'Singapore'], 'red', label="Singapore")
plt.plot(years, data.Taxrevenue[data["Country"] == 'Denmark'], 'brown', label="Denmark")
plt.plot(years, data.Taxrevenue[data["Country"] == 'China'], 'blue', label="China")
plt.plot(years, data.Taxrevenue[data["Country"] == 'UnitedStatesofAmerica'], 'black', label="USA")
plt.plot(years, data.Taxrevenue[data["Country"] == 'Pakistan'], 'green', label="Pakistan")
plt.plot(years, data.Taxrevenue[data["Country"] == 'India'], 'orange', label="India")


plt.title('Tax Revenue')
plt.legend()

# %%
plt.plot(years, data.Tradebalance[data["Country"] == 'Cyprus'], 'violet', label="Cyprus")
plt.plot(years, data.Tradebalance[data["Country"] == 'Singapore'], 'red', label="Singapore")
plt.plot(years, data.Tradebalance[data["Country"] == 'Denmark'], 'brown', label="Denmark")
plt.plot(years, data.Tradebalance[data["Country"] == 'China'], 'blue', label="China")
plt.plot(years, data.Tradebalance[data["Country"] == 'UnitedStatesofAmerica'], 'black', label="USA")
plt.plot(years, data.Tradebalance[data["Country"] == 'Pakistan'], 'green', label="Pakistan")
plt.plot(years, data.Tradebalance[data["Country"] == 'India'], 'orange', label="India")


plt.title('Trade Balance')
plt.legend()

# %%
plt.plot(years, data.Trafficdeaths[data["Country"] == 'Cyprus'], 'violet', label="Cyprus")
plt.plot(years, data.Trafficdeaths[data["Country"] == 'Singapore'], 'red', label="Singapore")
plt.plot(years, data.Trafficdeaths[data["Country"] == 'Denmark'], 'brown', label="Denmark")
plt.plot(years, data.Trafficdeaths[data["Country"] == 'China'], 'blue', label="China")
plt.plot(years, data.Trafficdeaths[data["Country"] == 'UnitedStatesofAmerica'], 'black', label="USA")
plt.plot(years, data.Trafficdeaths[data["Country"] == 'Pakistan'], 'green', label="Pakistan")
plt.plot(years, data.Trafficdeaths[data["Country"] == 'India'], 'orange', label="India")


plt.title('Traffic Deaths')
plt.legend()

# %%
plt.plot(years, data.Urbanpopulationgrowth[data["Country"] == 'Cyprus'], 'violet', label="Cyprus")
plt.plot(years, data.Urbanpopulationgrowth[data["Country"] == 'Singapore'], 'red', label="Singapore")
plt.plot(years, data.Urbanpopulationgrowth[data["Country"] == 'Denmark'], 'brown', label="Denmark")
plt.plot(years, data.Urbanpopulationgrowth[data["Country"] == 'China'], 'blue', label="China")
plt.plot(years, data.Urbanpopulationgrowth[data["Country"] == 'UnitedStatesofAmerica'], 'black', label="USA")
plt.plot(years, data.Urbanpopulationgrowth[data["Country"] == 'Pakistan'], 'green', label="Pakistan")
plt.plot(years, data.Urbanpopulationgrowth[data["Country"] == 'India'], 'orange', label="India")


plt.title('Urban Population Growth')
plt.legend()

# %%
plt.plot(years, data.YearlyCO2emission[data["Country"] == 'Cyprus'], 'violet', label="Cyprus")
plt.plot(years, data.YearlyCO2emission[data["Country"] == 'Singapore'], 'red', label="Singapore")
plt.plot(years, data.YearlyCO2emission[data["Country"] == 'Denmark'], 'brown', label="Denmark")
plt.plot(years, data.YearlyCO2emission[data["Country"] == 'China'], 'blue', label="China")
plt.plot(years, data.YearlyCO2emission[data["Country"] == 'UnitedStatesofAmerica'], 'black', label="USA")
plt.plot(years, data.YearlyCO2emission[data["Country"] == 'Pakistan'], 'green', label="Pakistan")
plt.plot(years, data.YearlyCO2emission[data["Country"] == 'India'], 'orange', label="India")


plt.title('Yearly CO2 Emission')
plt.legend()

# %%
pakistan_data = data[data["Country"] == 'Pakistan']
# Normalizing = "making range of each column same"
# Applying formula of normalizing value on each cell of each column 
for column in pakistan_data.columns:
    if column != 'Country':
        exact_column = pakistan_data[column]
        maxi = exact_column.max()
        mini = exact_column.min()
        for index, value in exact_column.iteritems():
            try:
                normalize_value = (value - mini)/(maxi - mini)
            except:
                normalize_value = (value - mini)
            pakistan_data.at[index, column] = normalize_value

for col in pakistan_data.columns:
    plt.plot(years, pakistan_data[col])
